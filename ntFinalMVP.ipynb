# %%
# Importa bibliotecas necessárias para requisições HTTP, manipulação de datas e dados, e operações com Spark
import requests  # Para realizar requisições à API dos pluviômetros
from datetime import datetime, timedelta  # Para manipular datas e horas
import pandas as pd  # Para manipulação de dados em DataFrames (utilizado em etapas específicas)
from delta.tables import DeltaTable  # Para operações com tabelas Delta no Lakehouse
from pyspark.sql.functions import col, max, min, current_timestamp  # Funções do PySpark para manipulação de colunas e timestamps
from pyspark.sql import functions as F  # Alias para funções do PySpark
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, LongType, TimestampType  # Tipos de dados para definição de schemas

# Dicionário de configuração contendo informações sobre as tabelas que serão utilizadas no Lakehouse
configTables = {
    "sensordata": {
        # Condição de junção para operações de merge entre dados existentes e novos
        "queryMerge": "t.sensorId = s.sensorId AND t.readingDate = s.readingDate",
        # Esquema (schema) da tabela 'sensordata', definindo os nomes e tipos de cada coluna
        "schema": StructType([
            StructField("sensorId", LongType(), True),  # ID único do sensor
            StructField("softSensorId", LongType(), True),  # ID do sensor virtual (soft sensor)
            StructField("readingDate", TimestampType(), True),  # Data e hora da leitura
            StructField("sensorValue", DoubleType(), True),  # Valor medido pelo sensor (precipitação em mm)
            StructField("deviceName", StringType(), True),  # Nome do dispositivo
            StructField("deviceId", LongType(), True),  # ID único do dispositivo
            StructField("sensorType", StringType(), True)  # Tipo do sensor
        ])
    },
    "softsensordata": {
        # Condição de junção para operações de merge entre dados existentes e novos
        "queryMerge": "t.softsensorId = s.softsensorId AND t.readingDate = s.readingDate",
        # Esquema (schema) da tabela 'softsensordata', com campos adicionais específicos para sensores virtuais
        "schema": StructType([
            StructField("sensorId", LongType(), True),  # ID único do sensor
            StructField("softSensorId", LongType(), True),  # ID do sensor virtual (soft sensor)
            StructField("readingDate", TimestampType(), True),  # Data e hora da leitura
            StructField("sensorValue", DoubleType(), True),  # Valor medido pelo sensor
            StructField("deviceName", StringType(), True),  # Nome do dispositivo
            StructField("deviceId", LongType(), True),  # ID único do dispositivo
            StructField("sensorType", StringType(), True),  # Tipo do sensor
            StructField("customName", StringType(), True)  # Nome personalizado atribuído ao sensor
        ])
    }
}
# Out:
# StatementMeta(, 36b874ce-9ff6-42d4-85e6-c8f9362a2c31, 21, Finished, Available, Finished)

# %%
# Classe responsável por se comunicar com a API fornecida pela empresa terceirizada dos pluviômetros.
# Essa classe encapsula os métodos de autenticação, obtenção de dispositivos e coleta de dados dos sensores.

class OrAPI:
    def __init__(self):
        # Chave de API usada para autenticar a requisição (substituída por 'X' por motivos de segurança)
        self.apiKey = "xXXXXXXXXXXXXXXXXXXXXXXXXXx" 
        # URL base da API fornecida pela empresa contratada
        self.url = "https://xxxxxxxxxxxxxxxxxxxx/api" 
        # Header com o token de autenticação (será obtido automaticamente no construtor)
        self.headers = self.getToken()

    # Função auxiliar para formatar datas no padrão esperado pela API
    def formatDate(self, date):
        return date.strftime("%Y-%m-%d %H:%M:%S")

    # Método que faz a requisição inicial para obter um token de acesso (Bearer Token)
    def getToken(self):
        params = {"apiKey" : self.apiKey}
        response = requests.get(self.url + '/token', params=params)

        # Se a requisição for bem-sucedida (status 200), retorna o header com token
        if(response.status_code == 200):
            token = response.json()['token']
            return {
                'Authorization': f'Bearer {token}'
            }

    # Método para buscar a lista de dispositivos (pluviômetros) cadastrados para o usuário
    def getUserDevices(self):
        if(self.headers):
            response = requests.get(self.url + "/userdevices", headers=self.headers)
            if(response.status_code == 200):
                return response.json()

    # Método que coleta os dados de sensores entre duas datas específicas
    # Permite filtrar por sensorId ou softSensorId
    def getSensorData(self, startDate, endDate, sensorIds = 0, softSensorIds = 0, numAttempts = 3):
        data = []

        if(self.headers):
            params = {
                "startDate": self.formatDate(startDate),  # Data inicial formatada
                "endDate": self.formatDate(endDate),      # Data final formatada
                "offset": 0                               # Parâmetro de paginação (caso necessário)
            }

            # Adiciona filtros opcionais para os sensores (físicos ou virtuais)
            if(sensorIds):
                params["sensorIds"] = sensorIds
            if(softSensorIds):
                params["softSensorIds"] = softSensorIds

            # Requisição à API para obter os dados do sensor
            response = requests.get(self.url + "/sensordata", params=params, headers=self.headers)

            if(response.status_code == 200):
                data = response.json()
            else:
                # Caso a requisição falhe, imprime código de erro e IDs dos sensores
                print("****Request Code: ", response.status_code, "SensorId:", sensorIds, "softSensorIds", softSensorIds)

            # Caso a resposta venha vazia, tenta novamente até esgotar o número de tentativas
            if(len(data) == 0 and numAttempts > 0):
                attempt = numAttempts - 1
                data = self.getSensorData(startDate, endDate, sensorIds, softSensorIds, numAttempts = attempt)

        return data
# Out:
# StatementMeta(, 36b874ce-9ff6-42d4-85e6-c8f9362a2c31, 22, Finished, Available, Finished)

# %%
class Repository:
    def __init__(self):
        # Inicializa o repositório com as configurações definidas
        # em configTables, que inclui os schemas e condições de merge para as tabelas.
        self.configTables = configTables

    def overwriteData(self, df, tableName):
        """
        Sobrescreve completamente os dados existentes na tabela Delta com o DataFrame fornecido.
        
        Essa função é útil em cargas iniciais ou quando uma reconstrução completa da tabela é necessária.
        
        Parâmetros:
        - df: DataFrame do PySpark contendo os dados que serão salvos.
        - tableName: Nome da tabela Delta no Lakehouse.
        """
        df.write.format("delta")\
            .mode("overwrite")\
            .option("overwriteSchema", "true")\
            .saveAsTable(tableName)

    def mergeData(self, df, tableName):
        """
        Realiza a atualização incremental (merge) dos dados na tabela Delta.
        
        Essa função verifica, utilizando a condição definida em configTables (queryMerge),
        se os registros já existem na tabela. Se existirem, os registros são atualizados;
        caso contrário, novos registros são inseridos.
        
        Isso possibilita armazenar os dados de forma incremental, evitando a necessidade
        de sobrescrever toda a tabela diariamente, o que melhora a performance das consultas.
        """
        config = self.configTables[tableName]  # Recupera a configuração específica da tabela

        # Carrega a tabela Delta existente no ambiente Spark.
        deltaTable = DeltaTable.forName(spark, tableName)

        # Realiza a operação de merge:
        # - 't' representa os dados existentes na tabela.
        # - 's' representa os novos dados (DataFrame).
        # A condição de junção é definida pela query em config["queryMerge"].
        # Atualiza todos os registros correspondentes ou insere os que não existem.
        deltaTable.alias("t").merge(
            df.alias("s"),
            config["queryMerge"]
        ).whenMatchedUpdateAll()\
         .whenNotMatchedInsertAll()\
         .execute()
# Out:
# StatementMeta(, 36b874ce-9ff6-42d4-85e6-c8f9362a2c31, 23, Finished, Available, Finished)

# %%
class DataCollectionService:
    def __init__(self):
        # Inicializa as configurações e instâncias necessárias para o processo de coleta
        self.configTables = configTables  # Configurações de schema e regras de merge definidas anteriormente
        self.OrAPI = OrAPI()  # Instância da classe OrAPI para realizar requisições à API dos pluviômetros
        self.repository = Repository()  # Instância da classe Repository para manipular os dados no Lakehouse
        
        # Inicializa variáveis para armazenar os dados coletados
        self.userDevices = None  # Lista de dispositivos (pluviômetros) obtidos a partir da API
        self.sensorDataList = []  # Lista para armazenar dados dos sensores físicos
        self.softSensorDataList = []  # Lista para armazenar dados dos sensores virtuais (soft sensors)
        self.processCollect = []  # Lista para registrar o progresso e detalhes da coleta de dados
        
        # DataFrames que serão criados a partir dos dados coletados
        self.dfSensorData = None  
        self.dfSoftSensorData = None
        self.dfUserDevices = None
        self.dfProcessCollect = None
        
        # Define o período para a coleta de dados
        self.days_to_subtract = 1  # Número de dias a subtrair para definir o início do período (ex: coleta dos dados do dia anterior)
        self.startDate = datetime.now() - timedelta(days=self.days_to_subtract)
        self.endDateFinal = datetime.now()  # Data final (atual) para o período de coleta

    def collectAndUpdateUserDevice(self):
        """
        Coleta a lista de dispositivos (pluviômetros) da API e atualiza a tabela 'devices' no Lakehouse.
        
        Para cada dispositivo:
        - Converte as strings de datas ('lastUpload' e 'dateInstalled') para objetos datetime.
        - Filtra os sensores, ignorando os do tipo 'Unallocated'.
        - Registra o número de sensores físicos e virtuais ativos.
        Por fim, converte os dados para um DataFrame do PySpark e sobrescreve a tabela 'devices'.
        """
        # Obtém os dispositivos a partir da API
        self.userDevices = self.OrAPI.getUserDevices()
        for item in self.userDevices:
            # Converte o campo 'lastUpload' para datetime (formato com fração de segundos)
            item['lastUpload'] = datetime.strptime(item['lastUpload'], '%Y-%m-%dT%H:%M:%S.%f')
            # Converte o campo 'dateInstalled' para datetime (formato sem fração de segundos)
            item['dateInstalled'] = datetime.strptime(item['dateInstalled'], '%Y-%m-%dT%H:%M:%S')
            
            # Filtra os sensores, considerando apenas aqueles que não devem ser ignorados (não são 'Unallocated')
            sensorActive = [s for s in item['sensors'] if self.sensorIngoreRequest(s)]
            softSensorsActive = [s for s in item['softSensors'] if self.sensorIngoreRequest(s)]
            
            # Armazena o número de sensores ativos em campos específicos
            item['numSensor'] = len(sensorActive)
            item['numSoftSensor'] = len(softSensorsActive)
        
        # Converte a lista de dispositivos (obtidos da API) de um DataFrame Pandas para um DataFrame PySpark
        self.dfUserDevices = spark.createDataFrame(self.userDevices)
        
        # Sobrescreve a tabela 'devices' no Lakehouse com o novo DataFrame
        self.repository.overwriteData(self.dfUserDevices, "devices")

    def sensorIngoreRequest(self, sensor):
        """
        Determina se um sensor deve ser ignorado com base no seu tipo.
        
        Parâmetro:
        - sensor: Dicionário contendo os dados de um sensor.
        
        Retorna:
        - True se o sensor NÃO for do tipo 'Unallocated'; caso contrário, False.
        """
        return sensor['sensorType'] != 'Unallocated'

    def getSensorData(self, startDate, endDate, userDevice, sensorNameList, sensorId):
        """
        Coleta os dados dos sensores para um dispositivo específico em um intervalo de tempo.
        
        Parâmetros:
        - startDate: Data inicial do período de coleta.
        - endDate: Data final do período de coleta.
        - userDevice: Dicionário com informações do dispositivo (inclui nome, ID e listas de sensores).
        - sensorNameList: Nome da lista a ser acessada no dispositivo ('sensors' ou 'softSensors').
        - sensorId: Chave que identifica o ID do sensor na lista (pode ser 'sensorId' ou 'softSensorId').
        
        Para cada sensor que não deve ser ignorado:
        - Requisita os dados dos sensores para o período definido.
        - Adiciona informações do dispositivo (nome e ID) e tipo do sensor aos registros retornados.
        - Para sensores virtuais (softSensors), adiciona o campo 'customName'.
        
        Imprime a quantidade de itens coletados e retorna a lista agregada de dados.
        """
        deviceName = userDevice['deviceName']
        deviceId = userDevice['deviceId']
        sensorDataList = []  # Lista para armazenar os dados coletados para esse dispositivo
        
        # Itera sobre cada sensor (ou soft sensor) do dispositivo
        for sensor in userDevice[sensorNameList]:
            # Apenas processa sensores que não são do tipo 'Unallocated'
            if self.sensorIngoreRequest(sensor):
                # Realiza a coleta dos dados conforme o tipo do sensor (físico ou virtual)
                if sensorNameList == 'sensors':
                    data = self.OrAPI.getSensorData(startDate, endDate, sensorIds=sensor[sensorId])
                else:
                    data = self.OrAPI.getSensorData(startDate, endDate, softSensorIds=sensor[sensorId])
                
                # Enriquecer cada registro com dados adicionais do dispositivo e do sensor
                for item in data:
                    item['deviceName'] = deviceName
                    item['deviceId'] = deviceId
                    item['sensorType'] = sensor['sensorType']
                    # Para soft sensors, adiciona o nome personalizado do sensor
                    if sensorNameList == 'softSensors':
                        item['customName'] = sensor['customName']
                
                # Acrescenta os dados coletados à lista geral para este dispositivo
                sensorDataList.extend(data)
        
        # Exibe no console o número de itens coletados para facilitar o monitoramento do processo
        print("Num Item: {} - {} items ".format(sensorNameList, len(sensorDataList)))
        return sensorDataList

    def parseDfSpark(self, data, tableName):
        """
        Processa a lista de dados coletados, realizando conversões necessárias, 
        removendo duplicatas e convertendo para um DataFrame do PySpark com o schema correto.
        
        Parâmetros:
        - data: Lista de dicionários com os dados dos sensores coletados.
        - tableName: Nome da tabela para a qual os dados serão convertidos ('sensordata' ou 'softsensordata').
        
        Retorna:
        - DataFrame do PySpark sem duplicatas.
        """
        config = self.configTables[tableName]  # Recupera o schema para a tabela especificada
        
        # Converte os campos de cada item para os tipos corretos
        for item in data:
            # Converte 'readingDate' (string) para objeto datetime
            item['readingDate'] = datetime.strptime(item['readingDate'], '%Y-%m-%dT%H:%M:%S')
            # Garante que 'sensorValue' seja tratado como float
            item['sensorValue'] = item['sensorValue'] * 1.0
        
        # Cria o DataFrame do PySpark utilizando o schema definido
        df = spark.createDataFrame(data, schema=config["schema"])
        # Remove duplicatas para garantir a consistência dos dados
        df_no_duplicates = df.dropDuplicates()
        
        return df_no_duplicates

    def registerProcessCollect(self, current_date, endDate, count, userDevice, userDevices, requestSensors):
        """
        Registra o progresso do processo de coleta de dados para cada dispositivo.
        
        Calcula e imprime a porcentagem de dispositivos processados e armazena as informações de progresso,
        como a data, o nome do dispositivo e a quantidade de sensores físicos e virtuais.
        
        Parâmetros:
        - current_date: Data de início do período atual de coleta.
        - endDate: Data final do período atual de coleta.
        - count: Contador que representa a ordem de processamento do dispositivo.
        - userDevice: Dicionário com as informações do dispositivo sendo processado.
        - userDevices: Lista com todos os dispositivos.
        - requestSensors: Lista com as configurações das requisições (para sensores e softSensors).
        """
        # Calcula a porcentagem de dispositivos processados
        percent = int(count * 100 / len(userDevices))
        print("\- {}% Collect Sensor Device: {} | Num Sensor: {}  | Num SoftSensor: {} ".format(
            percent, userDevice['deviceName'], len(userDevice['sensors']), len(userDevice['softSensors'])
        ))
        # Registra os dados do processo de coleta para esse dispositivo
        process = {
            "current_date": current_date,
            "endDate": endDate,
            "percent": percent,
            "deviceName": userDevice['deviceName'],
            "numSensor": len(userDevice['sensors']),
            "numSoftSensor": len(userDevice['softSensors']),
        }
        self.processCollect.append(process)

    def collectAndUpdateSensorData(self):
        """
        Função principal que gerencia a coleta e atualização dos dados dos sensores.
        
        Para cada dia no intervalo definido (entre startDate e endDateFinal):
        - Define o período diário (current_date até endDate).
        - Para cada dispositivo, coleta os dados dos sensores físicos e virtuais usando 'getSensorData'.
        - Registra o progresso da coleta por meio de 'registerProcessCollect'.
        - Incrementa o contador e o período para o próximo dia.
        
        Após a coleta:
        - Converte as listas de dados (sensorDataList e softSensorDataList) em DataFrames do PySpark com
          os schemas apropriados usando 'parseDfSpark'.
        - Realiza operações de merge incremental nos dados, atualizando as tabelas 'sensordata' e 'softsensordata'
          no Lakehouse por meio do método 'mergeData' da classe Repository.
        """
        # Inicia a coleta a partir do início do dia da data inicial (startDate)
        current_date = self.startDate.replace(hour=0, minute=0, second=0, microsecond=0)

        # Caso os dispositivos ainda não tenham sido coletados, obtém-os da API
        if self.userDevices is None:
            self.userDevices = self.OrAPI.getUserDevices()

        # Reinicia as listas de dados e de progresso
        self.sensorDataList = []
        self.softSensorDataList = []
        self.processCollect = []
        
        # Loop principal: coleta dados diariamente enquanto current_date for menor que endDateFinal
        while current_date < self.endDateFinal:
            endDate = current_date + timedelta(days=1)  # Define o fim do período de 1 dia
            count = 1  # Inicializa contador para dispositivos processados no dia
            
            # Exibe informações de progresso, incluindo número do dia e período de coleta
            print(
                (current_date - self.startDate.replace(hour=0, minute=0, second=0, microsecond=0)).days,
                "/", (self.endDateFinal - self.startDate).days,
                " | Init:", current_date,
                "Final:", endDate,
                " Period:", endDate - current_date
            )
            
            # Para cada dispositivo na lista de userDevices, coleta os dados dos sensores
            for userDevice in self.userDevices:
                # Caso queira filtrar dispositivos específicos, pode descomentar e utilizar a lista:
                # deviceNames = ['EWS6989 - Abrigo km 347','EWS6288 - Abrigo km 587']
                # if(userDevice['deviceName'] in deviceNames):
                
                # Define as configurações para coleta: uma para sensores físicos e outra para softSensors
                requestSensors = [
                    {"list": "sensors", "colId": "sensorId"},
                    {"list": "softSensors", "colId": "softSensorId"}
                ]
                for r in requestSensors:
                    # Coleta os dados para o período atual e para o tipo de sensor especificado
                    dataList = self.getSensorData(current_date, endDate, userDevice, r['list'], r['colId'])
                    # Acumula os dados na lista correspondente (físicos ou virtuais)
                    if r['list'] == "sensors":
                        self.sensorDataList.extend(dataList)
                    else:
                        self.softSensorDataList.extend(dataList)

                # Registra o progresso da coleta para o dispositivo atual
                self.registerProcessCollect(current_date, endDate, count, userDevice, self.userDevices, requestSensors)
                count += 1  # Incrementa o contador para o próximo dispositivo
            
            # Avança para o próximo dia
            current_date += timedelta(days=1)

        # Após a coleta, converte as listas de dados em DataFrames com o esquema definido
        self.dfSensorData = self.parseDfSpark(self.sensorDataList, "sensordata")
        self.dfSoftSensorData = self.parseDfSpark(self.softSensorDataList, "softsensordata")
        
        # Realiza a operação de merge incremental, atualizando as tabelas Delta no Lakehouse
        self.repository.mergeData(self.dfSensorData, "sensordata")
        self.repository.mergeData(self.dfSoftSensorData, "softsensordata")
# Out:
# StatementMeta(, 36b874ce-9ff6-42d4-85e6-c8f9362a2c31, 29, Finished, Available, Finished)

# %%
# Cria uma instância da classe DataCollectionService.
# Essa instância gerencia todo o processo de coleta e atualização dos dados dos
# pluviômetros: desde a obtenção das informações da API, passando pela transformação dos dados,
# até o armazenamento incremental no Lakehouse via operações de merge.
dataCollectionService = DataCollectionService()
# Out:
# StatementMeta(, 36b874ce-9ff6-42d4-85e6-c8f9362a2c31, 30, Finished, Available, Finished)

# %%
# Inicia o processo de coleta e atualização dos dados dos sensores dos pluviômetros.
# Este método coordena as seguintes etapas:
# 1. Coleta dos dados dos dispositivos para o período definido.
# 2. Requisição dos dados dos sensores (físicos e virtuais) para cada dispositivo.
# 3. Registro do progresso da coleta para monitoramento.
# 4. Conversão das listas coletadas em DataFrames do PySpark com o schema definido.
# 5. Atualização incremental das tabelas 'sensordata' e 'softsensordata' no Lakehouse,
#    utilizando operações de merge para inserir novos registros e atualizar os existentes.
dataCollectionService.collectAndUpdateSensorData()
# Out:
# StatementMeta(, 36b874ce-9ff6-42d4-85e6-c8f9362a2c31, 31, Finished, Available, Finished)
# 0 / 1  | Init: 2025-04-10 00:00:00 Final: 2025-04-11 00:00:00  Period: 1 day, 0:00:00
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 154 items
# Num Item: softSensors - 195 items
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 292 items
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 154 items
# Num Item: softSensors - 292 items
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# Num Item: sensors - 80 items
# Num Item: softSensors - 0 items
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 83 items
# Num Item: softSensors - 0 items
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 83 items
# Num Item: softSensors - 0 items
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 83 items
# Num Item: softSensors - 0 items
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 82 items
# Num Item: softSensors - 0 items
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 154 items
# Num Item: softSensors - 195 items
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 83 items
# Num Item: softSensors - 0 items
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 83 items
# Num Item: softSensors - 0 items
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# Num Item: sensors - 155 items
# Num Item: softSensors - 195 items
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 1 / 1  | Init: 2025-04-11 00:00:00 Final: 2025-04-12 00:00:00  Period: 1 day, 0:00:00
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 136 items
# Num Item: softSensors - 170 items
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 60 items
# Num Item: softSensors - 111 items
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 41 items
# Num Item: softSensors - 75 items
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# Num Item: sensors - 60 items
# Num Item: softSensors - 0 items
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 63 items
# Num Item: softSensors - 0 items
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 61 items
# Num Item: softSensors - 0 items
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 60 items
# Num Item: softSensors - 0 items
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 61 items
# Num Item: softSensors - 0 items
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 63 items
# Num Item: softSensors - 0 items
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# Num Item: sensors - 53 items
# Num Item: softSensors - 0 items
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# Num Item: sensors - 117 items
# Num Item: softSensors - 146 items
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3

# %% [markdown]
# # Teste e BackUp Códigos

# %%
dfSensordata = spark.read.table("sensordata")
# Out:
# StatementMeta(, de42de6d-14f0-4a9d-9f2e-3caf7c005ad4, 48, Finished, Available, Finished)

# %%
display(dfSensordata.groupBy('deviceName','sensorId').agg({"readingDate": "min"}))
# Out:
# StatementMeta(, de42de6d-14f0-4a9d-9f2e-3caf7c005ad4, 49, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 0df10e36-00a7-44e4-8b4c-93c942a20512)

# %%
dfSoftSensordata = spark.read.table("softsensordata")
# Out:
# StatementMeta(, de42de6d-14f0-4a9d-9f2e-3caf7c005ad4, 59, Finished, Available, Finished)

# %%
dfSoftSensorDataGroupDayWithoutData = dfSoftSensordata.groupBy('deviceName','customName').agg({"readingDate": "min", "readingDate": "max"})
# Out:
# StatementMeta(, de42de6d-14f0-4a9d-9f2e-3caf7c005ad4, 84, Finished, Available, Finished)

# %%
#dfSoftSensorDataGroupDayWithoutData["LastDataInDay"] = datetime.now() - dfSoftSensorDataGroupDayWithoutData['max(readingDate)']

from pyspark.sql.window import Window

windowSpec = Window.partitionBy('customName')


dfSoftSensorDataGroupDayWithoutData = dfSoftSensorDataGroupDayWithoutData.withColumn("LastDataInDay", current_timestamp() - col('max(readingDate)'))
# Out:
# StatementMeta(, de42de6d-14f0-4a9d-9f2e-3caf7c005ad4, 86, Finished, Available, Finished)

# %%
display(dfSoftSensorDataGroupDayWithoutData)
# Out:
# StatementMeta(, de42de6d-14f0-4a9d-9f2e-3caf7c005ad4, 88, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, e4e9623b-afa7-44f6-88da-2d1a095d38f1)

# %%
def sensorIngoreRequest(sensor):
    return sensor['sensorType'] != 'Unallocated'

sensorDataList = []
softSensorDataList = []    
current_date = startDate.replace(hour=0, minute=0, second=0, microsecond=0)
while current_date < endDate:
    end = current_date + timedelta(days=1)
    count = 1
    print(startDate - current_date,"/",startDate.day - endDate.day," | Init:" , current_date, "Final:",end ," Period:",end - current_date)
    for userDevice in userDevices:
        deviceName = userDevice['deviceName']
        deviceId   = userDevice['deviceId']
        percent = int(count*100/len(userDevices))
        print("\- {}% Collect Sensor Device: {} | Num Sensor:{}  | Num SoftSensor:{} ".format(percent,deviceName, len(userDevice['sensors']), len(userDevice['softSensors']) ) )
        for sensor in userDevice['sensors']:
            if(sensorIngoreRequest(sensor)):
                data = OrAPI.getSensorData(current_date,end,sensorIds = sensor['sensorId'])
                for item in data:
                    item['deviceName'] = deviceName
                    item['deviceId'] = deviceId
                    item['sensorType'] = sensor['sensorType']
                sensorDataList.extend(data)

        for softSensor in userDevice['softSensors']:
            if(sensorIngoreRequest(sensor)):
                data = OrAPI.getSensorData(current_date,end,softSensorIds = softSensor['softSensorId'])
                for item in data:
                    item['deviceName'] = deviceName
                    item['deviceId'] = deviceId
                    item['sensorType'] = softSensor['sensorType']
                    item['customName'] =softSensor['customName']
                softSensorDataList.extend(data)
        count += 1
    current_date += timedelta(days=1)
# Out:
# StatementMeta(, d3cbe9f8-95e4-4e08-8507-87a8ec067e4b, 8, Finished, Available, Finished)
# 0 / 16  | Init: 2025-03-27 00:00:00 Final: 2025-03-28 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# -1 / 16  | Init: 2025-03-28 00:00:00 Final: 2025-03-29 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# -2 / 16  | Init: 2025-03-29 00:00:00 Final: 2025-03-30 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# -3 / 16  | Init: 2025-03-30 00:00:00 Final: 2025-03-31 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# -4 / 16  | Init: 2025-03-31 00:00:00 Final: 2025-04-01 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 26 / 16  | Init: 2025-04-01 00:00:00 Final: 2025-04-02 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 25 / 16  | Init: 2025-04-02 00:00:00 Final: 2025-04-03 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 24 / 16  | Init: 2025-04-03 00:00:00 Final: 2025-04-04 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 23 / 16  | Init: 2025-04-04 00:00:00 Final: 2025-04-05 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 22 / 16  | Init: 2025-04-05 00:00:00 Final: 2025-04-06 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 21 / 16  | Init: 2025-04-06 00:00:00 Final: 2025-04-07 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 20 / 16  | Init: 2025-04-07 00:00:00 Final: 2025-04-08 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 19 / 16  | Init: 2025-04-08 00:00:00 Final: 2025-04-09 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 18 / 16  | Init: 2025-04-09 00:00:00 Final: 2025-04-10 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 17 / 16  | Init: 2025-04-10 00:00:00 Final: 2025-04-11 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3
# 16 / 16  | Init: 2025-04-11 00:00:00 Final: 2025-04-12 00:00:00  Period: 1 day, 0:00:00
# \- 3% Collect Sensor Device: EWS6989 - Abrigo km 035 | Num Sensor:7  | Num SoftSensor:3
# \- 7% Collect Sensor Device: EWS6985 - Abrigo km 409 | Num Sensor:7  | Num SoftSensor:3
# \- 10% Collect Sensor Device: EWS6984  - Abrigo km 807 | Num Sensor:7  | Num SoftSensor:3
# \- 14% Collect Sensor Device: EWS6998 - Abrigo km 70 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 17% Collect Sensor Device: EWS6977 - Abrigo km 193 | Num Sensor:7  | Num SoftSensor:3
# \- 21% Collect Sensor Device: EWS7002 - Abrigo km 11 (Ramal) | Num Sensor:7  | Num SoftSensor:5
# \- 25% Collect Sensor Device: EWS6737  - Abrigo km 629 | Num Sensor:7  | Num SoftSensor:3
# \- 28% Collect Sensor Device: EWS6966 - Abrigo km 244 | Num Sensor:7  | Num SoftSensor:3
# \- 32% Collect Sensor Device: EWS6973 - Abrigo km 51 (Ramal) | Num Sensor:7  | Num SoftSensor:3
# \- 35% Collect Sensor Device: EWS6949  - Abrigo km 371 | Num Sensor:13  | Num SoftSensor:3
# \- 39% Collect Sensor Device: EWS6536  - Abrigo km 149 | Num Sensor:13  | Num SoftSensor:5
# \- 42% Collect Sensor Device: EWS879 - Tilt 1 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 46% Collect Sensor Device: EWS6288 - Abrigo km 587 | Num Sensor:7  | Num SoftSensor:3
# \- 50% Collect Sensor Device: EWS6987 - Abrigo km 085 | Num Sensor:7  | Num SoftSensor:3
# \- 53% Collect Sensor Device: EWS6734  - Abrigo km 734 | Num Sensor:7  | Num SoftSensor:3
# \- 57% Collect Sensor Device: Ponto 1 - EWS895 | Num Sensor:7  | Num SoftSensor:0
# \- 60% Collect Sensor Device: Ponto 2 - EWS333 | Num Sensor:7  | Num SoftSensor:0
# \- 64% Collect Sensor Device: EWS875 - Tilt 2 (Pera do Pier - Aterro 3) | Num Sensor:7  | Num SoftSensor:0
# \- 67% Collect Sensor Device: Ponto 3 - EWS897 | Num Sensor:7  | Num SoftSensor:0
# \- 71% Collect Sensor Device: EWS6970  - Abrigo km 761 | Num Sensor:7  | Num SoftSensor:3
# \- 75% Collect Sensor Device: EWS5697 - Abrigo km 347 | Num Sensor:4  | Num SoftSensor:3
# \- 78% Collect Sensor Device: EWS6971  - Abrigo km 663 | Num Sensor:7  | Num SoftSensor:3
# \- 82% Collect Sensor Device: EWS6995 - Abrigo km 466 | Num Sensor:7  | Num SoftSensor:3
# \- 85% Collect Sensor Device: EWS6976 - Abrigo km 512 | Num Sensor:7  | Num SoftSensor:3
# \- 89% Collect Sensor Device: Ponto 5 - EWS458 | Num Sensor:5  | Num SoftSensor:0
# \- 92% Collect Sensor Device: EWS6958  - Abrigo km 295 | Num Sensor:7  | Num SoftSensor:3
# \- 96% Collect Sensor Device: Ponto 4 - EWS460 | Num Sensor:5  | Num SoftSensor:0
# \- 100% Collect Sensor Device: EWS6952 - Abrigo km 557 | Num Sensor:7  | Num SoftSensor:3

# %%
dfSensorData = pd.DataFrame(sensorDataList)
dfSensorData.fillna(0, inplace=True)
dfSensorData['readingDate'] = pd.to_datetime(dfSensorData['readingDate'])
dfSensorDataSpark = spark.createDataFrame(dfSensorData)
        # Salvar o DataFrame do SoftSensor em tabela formato Delta
dfSensorDataSpark.write.format("delta").mode("overwrite").saveAsTable('sensordata')
# Out:
# StatementMeta(, 67d92f8d-5234-4660-a801-bbc382d240ee, 12, Finished, Available, Finished)

# %%
dfSoftSensorData = pd.DataFrame(softSensorDataList)
dfSoftSensorData.fillna(0, inplace=True)
dfSoftSensorData['readingDate'] = pd.to_datetime(dfSoftSensorData['readingDate'])
dfSoftSensorData = spark.createDataFrame(dfSoftSensorData)
        # Salvar o DataFrame do SoftSensor em tabela formato Delta
dfSoftSensorData.write.format("delta").mode("overwrite").saveAsTable('softsensordata')
# Out:
# StatementMeta(, 67d92f8d-5234-4660-a801-bbc382d240ee, 13, Finished, Available, Finished)

# %%
#dfSensorDataSpark = dfSensorDataSpark.orderBy('readingDate')
dffilter =  dfSensorDataSpark.where((dfSensorDataSpark['sensorType'] == 'Air Temperature') & (dfSensorDataSpark['sensorValue'] > 0)  & (dfSensorDataSpark['sensorId'] == 87689) )
dffilter.orderBy('readingDate')
dffilter.select(max(col("readingDate"))).show()
# Out:
# StatementMeta(, 11899cbe-f972-45ed-ab1d-edaec7670138, 44, Finished, Available, Finished)
# +-------------------+
# |   max(readingDate)|
# +-------------------+
# |2025-04-09 22:00:00|
# +-------------------+

# %%
dfSensorDataSpark.where((dfSensorDataSpark['deviceId'] == 40635)).groupBy(['sensorType','sensorId']).agg(max('readingDate')).show()
# Out:
# StatementMeta(, 11899cbe-f972-45ed-ab1d-edaec7670138, 51, Finished, Available, Finished)
# +------------------+--------+-------------------+
# |        sensorType|sensorId|   max(readingDate)|
# +------------------+--------+-------------------+
# |Battery (External)|   82094|2025-03-30 03:00:00|
# |          Rainfall|   82095|2025-03-27 00:45:00|
# |   Air Temperature|   86631|2025-03-30 03:00:00|
# |           Battery|   82096|2025-04-08 03:15:00|
# +------------------+--------+-------------------+

# %%
count= 0
count =+ 1
count
# Out:
# StatementMeta(, dd446ec3-963e-4957-910c-a45bdd5fcd36, 8, Finished, Available, Finished)
# 1

# %%
repository.mergeSensorData(sensorDataList,"sensordata")
repository.mergeSensorData(softSensorDataList,"softsensordata")
# Out:
# StatementMeta(, 11899cbe-f972-45ed-ab1d-edaec7670138, 45, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 repository.mergeSensorData(sensorDataList,"sensordata")
#       2 repository.mergeSensorData(softSensorDataList,"softsensordata")
#
# Cell In[38], line 34, in Repository.mergeSensorData(self, data, tableName)
#      32 df['readingDate'] = pd.to_datetime(df['readingDate'])
#      33 df = spark.createDataFrame(df)
# ---> 34 self.mergeData(df,tableName)
#
# Cell In[38], line 21, in Repository.mergeData(self, df, tableName)
#      19 config = self.configTables[tableName]
#      20 # Carregar a tabela Delta existente
# ---> 21 deltaTable = DeltaTable.forName(spark, tableName)
#      23 # Definir a condição de junção e as ações de atualização/inserção
#      24 deltaTable.alias("t").merge(
#      25     df.alias("s"),
#      26     config["queryMerge"]                      #"t.sensorId = s.sensorId AND t.readingDate = s.readingDate"
#      27 ).whenMatchedUpdateAll().whenNotMatchedInsertAll().execute()
#
# File /usr/hdp/current/spark3-client/jars/delta-spark_2.12-3.2.0.15.jar/delta/tables.py:448, in DeltaTable.forName(cls, sparkSession, tableOrViewName)
#     445 jvm: "JVMView" = sparkSession._sc._jvm  # type: ignore[attr-defined]
#     446 jsparkSession: "JavaObject" = sparkSession._jsparkSession  # type: ignore[attr-defined]
# --> 448 jdt = jvm.io.delta.tables.DeltaTable.forName(jsparkSession, tableOrViewName)
#     449 return DeltaTable(sparkSession, jdt)
#
# File ~/cluster-env/trident_env/lib/python3.11/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [DELTA_MISSING_DELTA_TABLE] `sensordata` is not a Delta table.

# %%
df = pd.DataFrame(sensorDataList)
df['readingDate'] = pd.to_datetime(df['readingDate'])
df['readingDate'].max()
# Out:
# StatementMeta(, 656558c0-1531-4d96-a818-f7d1644bf3da, 32, Finished, Available, Finished)
# Timestamp('2025-04-08 00:00:00')

# %%
dfSensorData = pd.DataFrame(sensorDataList)
dfSensorData.fillna(0, inplace=True)
dfSensorDataSpark = spark.createDataFrame(dfSensorData)

dfSoftSensorData = pd.DataFrame(softSensorDataList)
dfSoftSensorData.fillna(0, inplace=True)
dfSoftSensorDataSpark = spark.createDataFrame(dfSoftSensorData)

# %%
userDevices
# Out:
# StatementMeta(, 656558c0-1531-4d96-a818-f7d1644bf3da, 25, Finished, Available, Finished)
# [{'deviceId': 40645,
#   'deviceName': 'EWS6989 - Abrigo km 035',
#   'reference': '6989',
#   'serialNumber': '301434061805050',
#   'dateInstalled': '2024-12-10T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:40.93',
#   'latitude': -2.903368,
#   'longitude': -44.364541,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 90526,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90160,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82146,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82147,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90528,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82148,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90158,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10353,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None},
#    {'softSensorId': 10354,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10355,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None}]},
#  {'deviceId': 40643,
#   'deviceName': 'EWS6985 - Abrigo km 409',
#   'reference': '6985',
#   'serialNumber': '301434060823820',
#   'dateInstalled': '2024-11-12T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:42.3',
#   'latitude': -4.387275,
#   'longitude': -46.79522,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 87692,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82139,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88463,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87691,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82138,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82141,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82140,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10124,
#     'sensorType': 'Rainfall',
#     'uom': 'mm/day',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10242,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10324,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 40641,
#   'deviceName': 'EWS6984  - Abrigo km 807',
#   'reference': '6984',
#   'serialNumber': '301434060728750',
#   'dateInstalled': '2024-11-05T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:40.533',
#   'latitude': -5.69352,
#   'longitude': -49.576976,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 82135,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87690,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87428,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87681,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82127,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82128,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82125,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10100,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10241,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10323,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 40648,
#   'deviceName': 'EWS6998 - Abrigo km 70 (Ramal)',
#   'reference': '6998',
#   'serialNumber': '301434061901380',
#   'dateInstalled': '2024-10-02T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:35.33',
#   'latitude': -6.404847,
#   'longitude': -50.088603,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 82157,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85730,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82160,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82158,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85936,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82159,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86203,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 9736,
#     'sensorType': 'Rainfall',
#     'uom': 'mm/day',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10088,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10244,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10327,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None},
#    {'softSensorId': 9755,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': None,
#     'scadaTag': None}]},
#  {'deviceId': 40640,
#   'deviceName': 'EWS6977 - Abrigo km 193',
#   'reference': '6977',
#   'serialNumber': '301434060722520',
#   'dateInstalled': '2024-12-07T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:35.61',
#   'latitude': -3.655962,
#   'longitude': -45.250715,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 82124,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90350,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90349,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82136,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82134,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90037,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82133,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10332,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None},
#    {'softSensorId': 10333,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10334,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None}]},
#  {'deviceId': 40649,
#   'deviceName': 'EWS7002 - Abrigo km 11 (Ramal)',
#   'reference': '7002',
#   'serialNumber': '301434061905110',
#   'dateInstalled': '2024-10-15T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:03:28.6',
#   'latitude': -6.044124,
#   'longitude': -49.852918,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 82161,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86205,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86661,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82163,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86630,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82162,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82164,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 9794,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10087,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10245,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10328,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None},
#    {'softSensorId': 10108,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia) testes',
#     'scadaTag': None}]},
#  {'deviceId': 40630,
#   'deviceName': 'EWS6737  - Abrigo km 629',
#   'reference': '6737',
#   'serialNumber': '301434060824730',
#   'dateInstalled': '2024-11-08T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:39.98',
#   'latitude': -5.159562,
#   'longitude': -48.261459,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 82076,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82073,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87499,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88164,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82075,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88163,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82074,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10110,
#     'sensorType': 'Rainfall',
#     'uom': 'mm/day',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10234,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10316,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 40633,
#   'deviceName': 'EWS6966 - Abrigo km 244',
#   'reference': '6966',
#   'serialNumber': '301434061909060',
#   'dateInstalled': '2024-12-09T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:42.35',
#   'latitude': -3.659438,
#   'longitude': -45.679897,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 82087,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90400,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90116,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82086,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82088,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90117,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90401,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10342,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None},
#    {'softSensorId': 10343,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10344,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None}]},
#  {'deviceId': 40637,
#   'deviceName': 'EWS6973 - Abrigo km 51 (Ramal)',
#   'reference': '6973',
#   'serialNumber': '301434061903150',
#   'dateInstalled': '2024-10-04T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:03:14.113',
#   'latitude': -6.306031,
#   'longitude': -50.000666,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 82113,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86204,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85729,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82115,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82114,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82112,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85934,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 9793,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10239,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10321,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 40631,
#   'deviceName': 'EWS6949  - Abrigo km 371',
#   'reference': '6949',
#   'serialNumber': '301434061900160',
#   'dateInstalled': '2024-11-12T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:36.977',
#   'latitude': -4.237279,
#   'longitude': -46.517555,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 87683,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82083,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87684,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '260',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88460,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87688,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '268',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82085,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87687,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '280',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87685,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '276',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87686,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '264',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82078,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87682,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '274',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82079,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87689,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10123,
#     'sensorType': 'Rainfall',
#     'uom': 'mm/day',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10235,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10317,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 39996,
#   'deviceName': 'EWS6536  - Abrigo km 149',
#   'reference': '6536',
#   'serialNumber': '301434060465170',
#   'dateInstalled': '2024-12-09T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:34.557',
#   'latitude': -3.543754,
#   'longitude': -44.891099,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 90119,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76130,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90121,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '308',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76150,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '4',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90402,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76153,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90120,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '288',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76154,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76156,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90123,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '272',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76132,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90122,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '259',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90118,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '15263',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10345,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None},
#    {'softSensorId': 10346,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10347,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10497,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': '24hr Aggregate',
#     'scadaTag': None},
#    {'softSensorId': 10498,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': '7day Aggregate',
#     'scadaTag': None}]},
#  {'deviceId': 40034,
#   'deviceName': 'EWS879 - Tilt 1 (Pera do Pier - Aterro 3)',
#   'reference': '879',
#   'serialNumber': '301434060724760',
#   'dateInstalled': '2025-01-08T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T09:02:31.307',
#   'latitude': -2.567203,
#   'longitude': -44.37454,
#   'batteryPercentage': 89,
#   'sensors': [{'sensorId': 76410,
#     'sensorType': 'Battery Non-Rechargeable',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90761,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76455,
#     'sensorType': 'A-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76415,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76447,
#     'sensorType': 'B-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 92211,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 76450,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': []},
#  {'deviceId': 39974,
#   'deviceName': 'EWS6288 - Abrigo km 587',
#   'reference': '6288',
#   'serialNumber': '300434068944120',
#   'dateInstalled': '2025-04-04T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:46.023',
#   'latitude': -5.150512,
#   'longitude': -47.89662,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 75790,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 75788,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 75789,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 75791,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85076,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85077,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 75792,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10579,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None},
#    {'softSensorId': 10928,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10929,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None}]},
#  {'deviceId': 40644,
#   'deviceName': 'EWS6987 - Abrigo km 085',
#   'reference': '6987',
#   'serialNumber': '301434061906080',
#   'dateInstalled': '2024-12-10T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:48.39',
#   'latitude': -3.298651,
#   'longitude': -44.465063,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 82142,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90525,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90527,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82144,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90159,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82145,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82143,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10350,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None},
#    {'softSensorId': 10351,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10352,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None}]},
#  {'deviceId': 40629,
#   'deviceName': 'EWS6734  - Abrigo km 734',
#   'reference': '6734',
#   'serialNumber': '301434061904090',
#   'dateInstalled': '2024-10-21T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:38.433',
#   'latitude': -5.383151,
#   'longitude': -49.088564,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 86794,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82072,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86793,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86602,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82071,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82070,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82069,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10083,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10233,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10314,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 40951,
#   'deviceName': 'Ponto 1 - EWS895',
#   'reference': '895',
#   'serialNumber': '301434061900450',
#   'dateInstalled': '2025-01-13T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:44.333',
#   'latitude': -4.750294,
#   'longitude': -47.306819,
#   'batteryPercentage': 100,
#   'sensors': [{'sensorId': 92414,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85314,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85389,
#     'sensorType': 'A-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85386,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85384,
#     'sensorType': 'B-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85319,
#     'sensorType': 'Battery Non-Rechargeable',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 92181,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': []},
#  {'deviceId': 38297,
#   'deviceName': 'Ponto 2 - EWS333',
#   'reference': '333',
#   'serialNumber': '300434068943840',
#   'dateInstalled': '2025-04-04T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:10:29.977',
#   'latitude': -4.750267,
#   'longitude': -47.30672,
#   'batteryPercentage': 99,
#   'sensors': [{'sensorId': 98317,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 94747,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 65363,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': None,
#     'scadaTag': None},
#    {'sensorId': 65364,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': None,
#     'scadaTag': None},
#    {'sensorId': 65362,
#     'sensorType': 'B-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '2',
#     'customName': None,
#     'scadaTag': None},
#    {'sensorId': 65365,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': None,
#     'scadaTag': None},
#    {'sensorId': 65361,
#     'sensorType': 'A-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '1',
#     'customName': None,
#     'scadaTag': None}],
#   'softSensors': []},
#  {'deviceId': 40752,
#   'deviceName': 'EWS875 - Tilt 2 (Pera do Pier - Aterro 3)',
#   'reference': 'EWS875',
#   'serialNumber': '301434060725750',
#   'dateInstalled': '2025-01-08T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:07:29.29',
#   'latitude': -2.567086,
#   'longitude': -44.37454,
#   'batteryPercentage': None,
#   'sensors': [{'sensorId': 82760,
#     'sensorType': 'B-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82761,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82755,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82759,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82758,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82756,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82757,
#     'sensorType': 'A-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': []},
#  {'deviceId': 40954,
#   'deviceName': 'Ponto 3 - EWS897',
#   'reference': '897',
#   'serialNumber': '301434061904430',
#   'dateInstalled': '2025-01-13T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:49.653',
#   'latitude': -4.750285,
#   'longitude': -47.306612,
#   'batteryPercentage': 89,
#   'sensors': [{'sensorId': 85318,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 92415,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85368,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85320,
#     'sensorType': 'Battery Non-Rechargeable',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85375,
#     'sensorType': 'B-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 85373,
#     'sensorType': 'A-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 92410,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': []},
#  {'deviceId': 40635,
#   'deviceName': 'EWS6970  - Abrigo km 761',
#   'reference': '6970',
#   'serialNumber': '301434061901170',
#   'dateInstalled': '2024-10-22T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:03:12.597',
#   'latitude': -5.558422,
#   'longitude': -49.228155,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 82094,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82095,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86885,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82097,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86631,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82096,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86884,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10082,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10237,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10319,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 42168,
#   'deviceName': 'EWS5697 - Abrigo km 347',
#   'reference': None,
#   'serialNumber': '300434068727750',
#   'dateInstalled': '2025-04-02T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:36.333',
#   'latitude': -4.081277,
#   'longitude': -46.370891,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 98321,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 98319,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 98320,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 98318,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10925,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10926,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10927,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 40636,
#   'deviceName': 'EWS6971  - Abrigo km 663',
#   'reference': '6971',
#   'serialNumber': '301434060827830',
#   'dateInstalled': '2024-11-07T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:15:09.38',
#   'latitude': -5.199419,
#   'longitude': -48.545946,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 82109,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82116,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88162,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 87498,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82111,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88161,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82110,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10111,
#     'sensorType': 'Rainfall',
#     'uom': 'mm/day',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10238,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10320,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 40647,
#   'deviceName': 'EWS6995 - Abrigo km 466',
#   'reference': '6995',
#   'serialNumber': '301434061909150',
#   'dateInstalled': '2024-11-13T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:40.453',
#   'latitude': -4.6114,
#   'longitude': -47.199573,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 88788,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88795,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82155,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88066,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82156,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82153,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82154,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10134,
#     'sensorType': 'Rainfall',
#     'uom': 'mm/day',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10243,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10326,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 40638,
#   'deviceName': 'EWS6976 - Abrigo km 512',
#   'reference': '6976',
#   'serialNumber': '301434060826790',
#   'dateInstalled': '2024-10-24T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:34.693',
#   'latitude': -4.904966,
#   'longitude': -47.39192,
#   'batteryPercentage': 105,
#   'sensors': [{'sensorId': 86952,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82117,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82118,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86951,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 86695,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82137,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82119,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10081,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10240,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10322,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]},
#  {'deviceId': 38820,
#   'deviceName': 'Ponto 5 - EWS458',
#   'reference': '458',
#   'serialNumber': '300434068050600',
#   'dateInstalled': '2025-01-13T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:03:04.673',
#   'latitude': -4.750113,
#   'longitude': -47.306809,
#   'batteryPercentage': 88,
#   'sensors': [{'sensorId': 68568,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 68569,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 68567,
#     'sensorType': 'B-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 68566,
#     'sensorType': 'A-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 68570,
#     'sensorType': 'Battery Non-Rechargeable',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': []},
#  {'deviceId': 40632,
#   'deviceName': 'EWS6958  - Abrigo km 295',
#   'reference': '6958',
#   'serialNumber': '301434061808220',
#   'dateInstalled': '2024-12-09T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:33.783',
#   'latitude': -3.732598,
#   'longitude': -46.104484,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 82084,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90398,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82082,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90115,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82081,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 90399,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82080,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10339,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None},
#    {'softSensorId': 10340,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10341,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None}]},
#  {'deviceId': 38827,
#   'deviceName': 'Ponto 4 - EWS460',
#   'reference': '460',
#   'serialNumber': '300434066744670',
#   'dateInstalled': '2025-01-13T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:44.42',
#   'latitude': -4.750122,
#   'longitude': -47.306926,
#   'batteryPercentage': 88,
#   'sensors': [{'sensorId': 68597,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 68599,
#     'sensorType': 'Battery Non-Rechargeable',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 68598,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 68596,
#     'sensorType': 'B-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 68595,
#     'sensorType': 'A-Axis Delta Angle',
#     'uom': 'Degrees',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': []},
#  {'deviceId': 40634,
#   'deviceName': 'EWS6952 - Abrigo km 557',
#   'reference': '6952',
#   'serialNumber': '301434061907450',
#   'dateInstalled': '2024-11-08T00:00:00',
#   'status': 'Online',
#   'lastUpload': '2025-04-10T12:02:36.423',
#   'latitude': -5.113592,
#   'longitude': -47.685811,
#   'batteryPercentage': 95,
#   'sensors': [{'sensorId': 87514,
#     'sensorType': 'Air Temperature',
#     'uom': 'Degs (C)',
#     'channelNumber': '3',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82089,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '256',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82092,
#     'sensorType': 'Battery (External)',
#     'uom': 'Volts',
#     'channelNumber': '2',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82090,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'channelNumber': '1',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88221,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '257',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 88220,
#     'sensorType': 'Unallocated',
#     'uom': 'Unallocated',
#     'channelNumber': '258',
#     'customName': '',
#     'scadaTag': ''},
#    {'sensorId': 82091,
#     'sensorType': 'Battery',
#     'uom': 'Volts',
#     'channelNumber': '999',
#     'customName': '',
#     'scadaTag': ''}],
#   'softSensors': [{'softSensorId': 10125,
#     'sensorType': 'Rainfall',
#     'uom': 'mm/day',
#     'customName': 'Precipitação (mm/dia)',
#     'scadaTag': None},
#    {'softSensorId': 10236,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimos 7 dias)',
#     'scadaTag': None},
#    {'softSensorId': 10318,
#     'sensorType': 'Rainfall',
#     'uom': 'mm',
#     'customName': 'Precipitação (acumulado últimas 24 horas)',
#     'scadaTag': None}]}]

# %%
# Converte o DataFrame Pandas para DataFrame PySpark


dfDevices = pd.DataFrame(userDevices)
dfDevices['lastUpload'] = pd.to_datetime(dfDevices['lastUpload'])
dfDevices['lastUpload'].max()
dfDevices = spark.createDataFrame(userDevices)
dfDevices.write.format("delta").mode("overwrite").saveAsTable("devices")
dfDevices.show()
# Out:
# StatementMeta(, 656558c0-1531-4d96-a818-f7d1644bf3da, 36, Finished, Available, Finished)
# +-----------------+-------------------+--------+--------------------+--------------------+---------+----------+---------+--------------------+---------------+--------------------+------+
# |batteryPercentage|      dateInstalled|deviceId|          deviceName|          lastUpload| latitude| longitude|reference|             sensors|   serialNumber|         softSensors|status|
# +-----------------+-------------------+--------+--------------------+--------------------+---------+----------+---------+--------------------+---------------+--------------------+------+
# |               95|2024-12-10T00:00:00|   40645|EWS6989 - Abrigo ...|2025-04-10T12:02:...|-2.903368|-44.364541|     6989|[{uom -> NULL, ch...|301434061805050|[{scadaTag -> NUL...|Online|
# |               95|2024-11-12T00:00:00|   40643|EWS6985 - Abrigo ...|2025-04-10T12:02:...|-4.387275| -46.79522|     6985|[{uom -> NULL, ch...|301434060823820|[{scadaTag -> NUL...|Online|
# |              105|2024-11-05T00:00:00|   40641|EWS6984  - Abrigo...|2025-04-10T12:02:...| -5.69352|-49.576976|     6984|[{uom -> NULL, ch...|301434060728750|[{scadaTag -> NUL...|Online|
# |              105|2024-10-02T00:00:00|   40648|EWS6998 - Abrigo ...|2025-04-10T12:02:...|-6.404847|-50.088603|     6998|[{uom -> NULL, ch...|301434061901380|[{scadaTag -> NUL...|Online|
# |              105|2024-12-07T00:00:00|   40640|EWS6977 - Abrigo ...|2025-04-10T12:02:...|-3.655962|-45.250715|     6977|[{uom -> NULL, ch...|301434060722520|[{scadaTag -> NUL...|Online|
# |              105|2024-10-15T00:00:00|   40649|EWS7002 - Abrigo ...|2025-04-10T12:03:...|-6.044124|-49.852918|     7002|[{uom -> NULL, ch...|301434061905110|[{scadaTag -> NUL...|Online|
# |               95|2024-11-08T00:00:00|   40630|EWS6737  - Abrigo...|2025-04-10T12:02:...|-5.159562|-48.261459|     6737|[{uom -> NULL, ch...|301434060824730|[{scadaTag -> NUL...|Online|
# |              105|2024-12-09T00:00:00|   40633|EWS6966 - Abrigo ...|2025-04-10T12:02:...|-3.659438|-45.679897|     6966|[{uom -> NULL, ch...|301434061909060|[{scadaTag -> NUL...|Online|
# |              105|2024-10-04T00:00:00|   40637|EWS6973 - Abrigo ...|2025-04-10T12:03:...|-6.306031|-50.000666|     6973|[{uom -> NULL, ch...|301434061903150|[{scadaTag -> NUL...|Online|
# |              105|2024-11-12T00:00:00|   40631|EWS6949  - Abrigo...|2025-04-10T12:02:...|-4.237279|-46.517555|     6949|[{uom -> NULL, ch...|301434061900160|[{scadaTag -> NUL...|Online|
# |               95|2024-12-09T00:00:00|   39996|EWS6536  - Abrigo...|2025-04-10T12:02:...|-3.543754|-44.891099|     6536|[{uom -> NULL, ch...|301434060465170|[{scadaTag -> NUL...|Online|
# |               89|2025-01-08T00:00:00|   40034|EWS879 - Tilt 1 (...|2025-04-10T09:02:...|-2.567203| -44.37454|      879|[{uom -> NULL, ch...|301434060724760|                  []|Online|
# |               95|2025-04-04T00:00:00|   39974|EWS6288 - Abrigo ...|2025-04-10T12:02:...|-5.150512| -47.89662|     6288|[{uom -> NULL, ch...|300434068944120|[{scadaTag -> NUL...|Online|
# |              105|2024-12-10T00:00:00|   40644|EWS6987 - Abrigo ...|2025-04-10T12:02:...|-3.298651|-44.465063|     6987|[{uom -> NULL, ch...|301434061906080|[{scadaTag -> NUL...|Online|
# |               95|2024-10-21T00:00:00|   40629|EWS6734  - Abrigo...|2025-04-10T12:02:...|-5.383151|-49.088564|     6734|[{uom -> NULL, ch...|301434061904090|[{scadaTag -> NUL...|Online|
# |              100|2025-01-13T00:00:00|   40951|    Ponto 1 - EWS895|2025-04-10T12:02:...|-4.750294|-47.306819|      895|[{uom -> NULL, ch...|301434061900450|                  []|Online|
# |               99|2025-04-04T00:00:00|   38297|    Ponto 2 - EWS333|2025-04-10T12:10:...|-4.750267| -47.30672|      333|[{uom -> NULL, ch...|300434068943840|                  []|Online|
# |             NULL|2025-01-08T00:00:00|   40752|EWS875 - Tilt 2 (...|2025-04-10T12:07:...|-2.567086| -44.37454|   EWS875|[{uom -> NULL, ch...|301434060725750|                  []|Online|
# |               89|2025-01-13T00:00:00|   40954|    Ponto 3 - EWS897|2025-04-10T12:02:...|-4.750285|-47.306612|      897|[{uom -> NULL, ch...|301434061904430|                  []|Online|
# |               95|2024-10-22T00:00:00|   40635|EWS6970  - Abrigo...|2025-04-10T12:03:...|-5.558422|-49.228155|     6970|[{uom -> NULL, ch...|301434061901170|[{scadaTag -> NUL...|Online|
# +-----------------+-------------------+--------+--------------------+--------------------+---------+----------+---------+--------------------+---------------+--------------------+------+
# only showing top 20 rows

# %% [markdown]
# #### Criar Tabela Devices

# %%
# Converte o DataFrame Pandas para DataFrame PySpark
dfDevices = spark.createDataFrame(userDevices)

# Salvar o DataFrame do SoftSensor em tabela formato Delta
dfDevices.write.format("delta").mode("overwrite").saveAsTable("devices")


# from pyspark.sql.types import StructType, StructField, StringType, LongType, DoubleType, TimestampType

# # Definir o esquema das colunas
# schema = StructType([
#     StructField("sensorId", LongType(), True),
#     StructField("readingDate", TimestampType(), True),
#     StructField("sensorValue", DoubleType(), True),
#     StructField("deviceName", StringType(), True),
#     StructField("deviceId", LongType(), True),
#     StructField("sensorType", StringType(), True)
# ])

# # Criar o DataFrame com o esquema definido
# #dfSensorDataSpark = spark.createDataFrame(dfSensorDataSpark.rdd, schema)
# dfSensorDataSpark = spark.createDataFrame(dfSensorData, schema)
# # Salvar o DataFrame em formato Delta com o esquema definido
# dfSensorDataSpark.write.format("delta").mode("overwrite").saveAsTable("sensordata")
# Out:
# StatementMeta(, 656558c0-1531-4d96-a818-f7d1644bf3da, 27, Finished, Available, Finished)

# %% [markdown]
# #### Sensor Data

# %%
# Carregar a tabela Delta existente
deltaTable = DeltaTable.forName(spark, "sensordata")

# Definir a condição de junção e as ações de atualização/inserção
deltaTable.alias("t").merge(
    dfSensorDataSpark.alias("s"),
    "t.sensorId = s.sensorId AND t.readingDate = s.readingDate"
).whenMatchedUpdateAll().whenNotMatchedInsertAll().execute()

dfSensorDataSpark.show()
# Out:
# StatementMeta(, b64da358-674f-4305-b897-066987a34b81, 16, Finished, Available, Finished)
# +--------+------------+-------------------+------------------+--------------------+--------+----------+
# |sensorId|softSensorId|        readingDate|       sensorValue|          deviceName|deviceId|sensorType|
# +--------+------------+-------------------+------------------+--------------------+--------+----------+
# |   75788|           0|2025-04-08T00:00:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T00:15:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T00:30:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T00:45:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T01:00:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T01:15:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T01:30:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T01:45:00|0.6000000238418579|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T02:00:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T02:15:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T02:30:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T02:45:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T03:00:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T03:15:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T03:30:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T03:45:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T04:00:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T04:15:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T04:30:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# |   75788|           0|2025-04-08T04:45:00|               0.0|EWS6288 - Abrigo ...|   39974|  Rainfall|
# +--------+------------+-------------------+------------------+--------------------+--------+----------+
# only showing top 20 rows

# %% [markdown]
# #### Soft Sebsor Data

# %%
# Carregar a tabela Delta existente
deltaTable = DeltaTable.forName(spark, "softsensordata")

# Definir a condição de junção e as ações de atualização/inserção
deltaTable.alias("t").merge(
    dfSoftSensorDataSpark.alias("s"),
    "t.softsensorId = s.softsensorId AND t.readingDate = s.readingDate"
).whenMatchedUpdateAll().whenNotMatchedInsertAll().execute()

dfSoftSensorDataSpark.show()
# Out:
# StatementMeta(, b64da358-674f-4305-b897-066987a34b81, 17, Finished, Available, Finished)
# +--------+------------+-------------------+------------------+--------------------+--------+----------+----+--------------------+
# |sensorId|softSensorId|        readingDate|       sensorValue|          deviceName|deviceId|sensorType| uom|          customName|
# +--------+------------+-------------------+------------------+--------------------+--------+----------+----+--------------------+
# |   82072|       10083|2025-04-08T23:59:00|0.6000000089406967|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (mm/...|
# |   82072|       10233|2025-04-08T00:00:00| 44.19999976456165|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T00:15:00| 38.39999967813492|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T00:30:00| 38.59999968111515|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T00:45:00| 38.59999968111515|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T01:00:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T01:15:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T01:30:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T01:45:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T02:00:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T02:15:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T02:30:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T02:45:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T03:00:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T03:15:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T03:30:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T03:45:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T04:00:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T04:15:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# |   82072|       10233|2025-04-08T04:30:00| 38.79999968409538|EWS6734  - Abrigo...|   40629|  Rainfall|[mm]|Precipitação (acu...|
# +--------+------------+-------------------+------------------+--------------------+--------+----------+----+--------------------+
# only showing top 20 rows

# %%
dfSensorDataSpark = dfSensorDataSpark.orderBy('readingDate')
dfSensorDataSpark.where((dfSensorDataSpark['sensorType'] == 'Unallocated') & (dfSensorDataSpark['sensorId'] == 86793)).show()
# Out:
# StatementMeta(, 9658dc7a-5399-4866-8b1f-b7117dfe2618, 25, Finished, Available, Finished)
# +--------+------------+-----------+-----------+----------+--------+----------+
# |sensorId|softSensorId|readingDate|sensorValue|deviceName|deviceId|sensorType|
# +--------+------------+-----------+-----------+----------+--------+----------+
# +--------+------------+-----------+-----------+----------+--------+----------+

# %%
sensorDataList[0]['readingDate']
# Out:
# StatementMeta(, d3cbe9f8-95e4-4e08-8507-87a8ec067e4b, 17, Finished, Available, Finished)
# datetime.datetime(2025, 3, 27, 0, 0)

# %%
display(dfSensorDataSpark)
# Out:
# StatementMeta(, c764ddb8-8fb2-40ec-b02b-278de5696488, 23, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, c3c96fd3-0dea-4ca6-a45e-9a3934f6d65a)

# %%
# Converte a string de data para objeto datetime

for item in dataCollectionService.sensorDataList:
    #item['readingDate'] = datetime.strptime(item['readingDate'], '%Y-%m-%dT%H:%M:%S')
    item['sensorValue'] = item['sensorValue']*1.0

# Define o esquema com tipos consistentes
schema = StructType([
    StructField("sensorId", LongType(), True),
    StructField("softSensorId", LongType(), True),
    StructField("readingDate", TimestampType(), True),
    StructField("sensorValue", DoubleType(), True),
    StructField("deviceName", StringType(), True),
    StructField("deviceId", LongType(), True),
    StructField("sensorType", StringType(), True)
])

dfSensorDataSpark = spark.createDataFrame(dataCollectionService.sensorDataList,schema)
# Out:
# StatementMeta(, c764ddb8-8fb2-40ec-b02b-278de5696488, 18, Finished, Available, Finished)

# %%
display(dfSensorDataSpark.groupBy("sensorId","readingDate").agg({"sensorValue": "count"}))
# Out:
# StatementMeta(, c764ddb8-8fb2-40ec-b02b-278de5696488, 25, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, cde551dd-0e93-42a1-8d5e-4bc16657b7b5)

# %%
dfSensorDataSpark.write.format("delta").mode("overwrite").saveAsTable("testdevices")
# Out:
# StatementMeta(, d3cbe9f8-95e4-4e08-8507-87a8ec067e4b, 18, Finished, Available, Finished)

# %%
softSensorDataList[0]['readingDate']
# Out:
# StatementMeta(, d3cbe9f8-95e4-4e08-8507-87a8ec067e4b, 16, Finished, Available, Finished)
# datetime.datetime(2025, 3, 27, 23, 59)

# %%
# Converte a string de data para objeto datetime

for item in softSensorDataList:
    item['readingDate'] = datetime.strptime(item['readingDate'], '%Y-%m-%dT%H:%M:%S')
    item['sensorValue'] = item['sensorValue']*1.0

# Define o esquema com tipos consistentes
schema = StructType([
    StructField("sensorId", LongType(), True),
    StructField("softSensorId", LongType(), True),
    StructField("readingDate", TimestampType(), True),
    StructField("sensorValue", DoubleType(), True),
    StructField("deviceName", StringType(), True),
    StructField("deviceId", LongType(), True),
    StructField("sensorType", StringType(), True),
    StructField("customName", StringType(), True)
])

dfSoftSensorDataSpark = spark.createDataFrame(softSensorDataList,schema)

dfSoftSensorDataSpark.write.format("delta").mode("overwrite").saveAsTable("softsensordata")
# Out:
# StatementMeta(, d3cbe9f8-95e4-4e08-8507-87a8ec067e4b, 14, Finished, Available, Finished)

# %%
display(dfSoftSensorDataSpark)
# Out:
# StatementMeta(, d3cbe9f8-95e4-4e08-8507-87a8ec067e4b, 15, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 488eca35-5a9b-407d-87f3-fae48a5bc272)
